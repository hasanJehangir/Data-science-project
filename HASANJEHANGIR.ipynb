# %% [markdown]
# # data requirement

# %% [markdown]
# *In this step we after understanding business and analytic approach we think about what kind of data is required for us to predict best answer for the problem given by stackholder. for this mini project DR. Suhail Yousaf have given us data.*

# %% [markdown]
# # data collection

# %% [markdown]
# *In this step we collect the data required for solving the problem. there are many ways of collecting the data looking at the need of problem type. we have given data already of house pricing.we have rows and columns in data. also various kind of data i-e categorical and numerical is present in given data*

# %% [markdown]
# # data understanding

# %% [markdown]
# *here we will understand the data given to us or collected by us*

# %% [markdown]
# ***importing libraries***

# %%
import pandas as pd  #use panda library for data structure
import numpy as np #use numpy for array

# %% [markdown]
# ***DATA READING AND WRITING***

# %%
df = pd.read_csv("C:\\Users\\CVA\\Desktop\\Introduction to Data Science\\housing data.csv")  #giving path of dataset

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# **CHECKING DATA TYPE**

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice        float64
# Length: 81, dtype: object

# %% [markdown]
# **Recalling statistics of data to understand data**

# %%
df.describe(include = "all")
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   2919.000000  2919.000000     2915  2433.000000    2919.000000   2919
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     2265          NaN            NaN   2907
# mean    1460.000000    57.137718      NaN    69.305795   10168.114080    NaN
# std      842.787043    42.517628      NaN    23.344905    7886.996359    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      730.500000    20.000000      NaN    59.000000    7478.000000    NaN
# 50%     1460.000000    50.000000      NaN    68.000000    9453.000000    NaN
# 75%     2189.500000    70.000000      NaN    80.000000   11570.000000    NaN
# max     2919.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %% [markdown]
# ***Checking info of whole dataset***

# %%
df.info
# Out:
# <bound method DataFrame.info of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 2914  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2915  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2916  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2917  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2918  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ***DELETING THOSE COLUMN WHICH HAVE NO EFFECT ON DATASET***

# %%
df.drop(columns=['PoolArea','PoolQC','3SsnPorch','ScreenPorch'], inplace=True) #delete column as they are of no use

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# **view some statistical detail of updated data**

# %%
df.describe(include = "all")
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   2919.000000  2919.000000     2915  2433.000000    2919.000000   2919
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     2265          NaN            NaN   2907
# mean    1460.000000    57.137718      NaN    69.305795   10168.114080    NaN
# std      842.787043    42.517628      NaN    23.344905    7886.996359    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      730.500000    20.000000      NaN    59.000000    7478.000000    NaN
# 50%     1460.000000    50.000000      NaN    68.000000    9453.000000    NaN
# 75%     2189.500000    70.000000      NaN    80.000000   11570.000000    NaN
# max     2919.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %% [markdown]
# **REMOVING DUPLICATE VALUES**

# %%
df.info()
df.duplicated(subset=None, keep="first")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2433 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
# ...

# %% [markdown]
# **looking for missing data**

# %%
df.isna().sum().sum()
# Out:
# 12515

# %%
missed = df.isna().sum()
missed.plot(kind = "bar",figsize=(20,10))# sns.barplot(x=data_f.columns)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 2914  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2915  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2916  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2917  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2918  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
df.isnull()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 2914  False       False     False        False    False   False   True
# 2915  False       False     False        False    False   False   True
# 2916  False       False     False        False    False   False   True
# 2917  False       False     False        False    False   False   True
# 2918  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# ...

# %%
 df.dropna(subset=["SalePrice"], inplace=True)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# **BINNING OF PRICE**

# %%
df["SalePrice"].replace("?", np.nan, inplace = True)
df["SalePrice"] = pd.to_numeric(df["SalePrice"])

bins = np.linspace(min(df["SalePrice"]), max(df["SalePrice"]), 4)

# %%
bins
# Out:
# array([ 34900.        , 274933.33333333, 514966.66666667, 755000.        ])

# %%
group_names = ["Low", "Medium", "High"]

# %%
df["Priced-binned"] = pd.cut(df["SalePrice"],bins, labels=group_names, include_lowest = True)

# %%
df[ ["SalePrice", "Priced-binned"] ]
# Out:
#       SalePrice Priced-binned
# 0      208500.0           Low
# 1      181500.0           Low
# 2      223500.0           Low
# 3      140000.0           Low
# 4      250000.0           Low
# ...         ...           ...
# 1455   175000.0           Low
# 1456   210000.0           Low
# 1457   266500.0           Low
# 1458   142125.0           Low
# 1459   147500.0           Low
#
# [1460 rows x 2 columns]

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# *we have checked all the data and it is now clear. so now go for some visualization*

# %%
import seaborn as sns

x = df.SalePrice
sns.set_style("whitegrid")
sns.distplot(x)
plt.show()

df["SalePrice_log"] = np.log(df.SalePrice)
x = df.SalePrice_log
sns.distplot(x)
plt.show()
# Out:
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **CORELATION BETWEEN VARIABLES**

# %%
# Lets explore the correlations in our data set
plt.figure(figsize=(20, 20))
sns.heatmap(df.corr())
plt.savefig("pearsonsmep.png")

# %% [markdown]
# **The correlation measure used here is Pearson’s correlation. In our case the lighter the square the stronger the correlation between two variables.**

# %%
import seaborn as sns
sns.regplot(x="SalePrice", y = "LotArea", data=df)
plt.ylim(0,)
plt.xlabel("SalePrice")
plt.title("Correlation b/w LotArea and SalePrice")
# Out:
# Text(0.5, 1.0, 'Correlation b/w LotArea and SalePrice')

# %% [markdown]
# **finding all variables who are strongy corelated to price of house and then visualizing it**

# %%
select_dtype = df.select_dtypes(include = ['float64', 'int64'])
correlation = select_dtype.corr()['SalePrice'] 
top_features = correlation[abs(correlation) > 0.5].sort_values(ascending=True) #displays pearsons correlation coefficient greater than 0.7
print("There are {}  strongly correlated values with SalePrice:\n{}".format(len(top_features), top_features))
# Out:
# There are 12  strongly correlated values with SalePrice:
# YearRemodAdd     0.507101
# YearBuilt        0.522897
# TotRmsAbvGrd     0.533723
# FullBath         0.560664
# 1stFlrSF         0.605852
# TotalBsmtSF      0.613581
# GarageArea       0.623431
# GarageCars       0.640409
# GrLivArea        0.708624
# OverallQual      0.790982
# SalePrice_log    0.948374
# SalePrice        1.000000
# Name: SalePrice, dtype: float64

# %%
for i in range(0, len(select_dtype.columns), 5):
    sns.pairplot(data=select_dtype,
                x_vars=select_dtype.columns[i:i+5],
                y_vars=['SalePrice'])

# %% [markdown]
# ***from above graphs we can know about strong correlate variable with price***

# %% [markdown]
# **Analysis for categorical variables**

# %%
features = df.select_dtypes(include=['object']).columns

for features in features:
    g = sns.FacetGrid(df, col=features)
    g.map(plt.hist, 'SalePrice');
# Out:
# E:\Anaconda\lib\site-packages\seaborn\axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)

# %% [markdown]
# *MOST HOUSES ARE IN NORMAL CONDITION*

# %% [markdown]
# # #checking skewness

# %%
sp_untransformed = sns.distplot(df['SalePrice'])
print("Skewness: %f" % df['SalePrice'].skew())
# Out:
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Skewness: 1.882876

# %% [markdown]
# **SalePrice' deviates from the normal distribution. It has a longer tail to the right**

# %% [markdown]
# *NOW CHECKING SKEWNESS OF VARIABLES FROM PRICE*

# %%
sk1=df.dtypes==np.float64
sk2=df.dtypes==np.int64

fl=df.columns[sk1]
f2=df.columns[sk2]
sk_limit=0.50
sk_value1=df[fl].skew()
sk_value2=df[f2].skew()
log_transfer=np.log(sk_value1)
log_transfer=np.log(sk_value2)
total=sk_value1+sk_value2
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# E:\Anaconda\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
skew_cols = (sk_value2
             .sort_values(ascending=False)
             .to_frame()
             .rename(columns={0:'Skew'})
             .query('abs(Skew) > {}'.format(sk_limit)))

skew_cols
# Out:
#                     Skew
# MiscVal        24.476794
# LotArea        12.207688
# LowQualFinSF    9.011341
# KitchenAbvGr    4.488397
# EnclosedPorch   3.089872
# OpenPorchSF     2.364342
# WoodDeckSF      1.541376
# MSSubClass      1.407657
# 1stFlrSF        1.376757
# GrLivArea       1.366560
# 2ndFlrSF        0.813030
# OverallCond     0.693067
# TotRmsAbvGrd    0.676341
# HalfBath        0.675897
# Fireplaces      0.649565
# YearRemodAdd   -0.503562
# YearBuilt      -0.613461

# %%
skew_cols = (sk_value1
             .sort_values(ascending=False)
             .to_frame()
             .rename(columns={0:'Skew'})
             .query('abs(Skew) > {}'.format(sk_limit)))

skew_cols
# Out:
#                   Skew
# BsmtFinSF2    4.255261
# BsmtHalfBath  4.103403
# MasVnrArea    2.669084
# LotFrontage   2.163569
# SalePrice     1.882876
# BsmtFinSF1    1.685503
# TotalBsmtSF   1.524255
# BsmtUnfSF     0.920268
# BsmtFullBath  0.596067
# GarageYrBlt  -0.649415

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# **we have clean data ready for modeling**

# %% [markdown]
# # DATA MODELING

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
X = df[['OverallQual','YearBuilt','YearRemodAdd','TotalBsmtSF','1stFlrSF','GrLivArea','FullBath','TotRmsAbvGrd','GarageCars','GarageArea']]
Y = df['SalePrice']

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm.predict(X)

# %%
lm.intercept_
# Out:
# -1186193.766666144

# %%
lm.coef_
# Out:
# array([ 1.96045898e+04,  2.68240707e+02,  2.96481161e+02,  1.98650991e+01,
#         1.41737355e+01,  5.12971178e+01, -6.79087146e+03,  3.31050771e+01,
#         1.04179010e+04,  1.49475334e+01])

# %% [markdown]
# ## Yhat=a + b1X1 + b2X2 + b3X3 +  b4X4 + b5X5 + b6X6 + b7X7+ b8X8+ b9X9+ b10X10

# %% [markdown]
# *as it is multi linear regression so our final model is above*

# %% [markdown]
# # EVALUATION

# %%
Y_hat = lm.predict(df[['OverallQual','YearBuilt','YearRemodAdd','TotalBsmtSF','1stFlrSF','GrLivArea','FullBath','TotRmsAbvGrd','GarageCars','GarageArea']])

# %%
plt.figure(figsize=(10, 10))


ax1 = sns.distplot(df['SalePrice'], hist=False, color="r", label="Actual Value")
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for SalePrice')
plt.xlabel('SalePrice')
plt.ylabel('Parameter')

plt.show()
plt.close()
# Out:
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# E:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
